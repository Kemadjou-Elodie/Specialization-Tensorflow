# %% [markdown]
# # Ungraded Lab: Build a Multi-output Model
#
# In this lab, we'll show how you can build models with more than one output. The dataset we will be working on is available from the [UCI Machine Learning Repository](https://archive.ics.uci.edu/ml/datasets/Energy+efficiency). It is an Energy Efficiency dataset which uses the bulding features (e.g. wall area, roof area) as inputs and has two outputs: Cooling Load and Heating Load. Let's see how we can build a model to train on this data.

# %% [markdown]
# ## Imports

# %%
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Utilities
#
# We define a few utilities for data conversion and visualization to make our code more neat.

# %%
def format_output(data):
    y1 = data.pop('Y1')
    y1 = np.array(y1)
    y2 = data.pop('Y2')
    y2 = np.array(y2)
    return y1, y2


def norm(x):
    return (x - train_stats['mean']) / train_stats['std']


def plot_diff(y_true, y_pred, title=''):
    plt.scatter(y_true, y_pred)
    plt.title(title)
    plt.xlabel('True Values')
    plt.ylabel('Predictions')
    plt.axis('equal')
    plt.axis('square')
    plt.xlim(plt.xlim())
    plt.ylim(plt.ylim())
    plt.plot([-100, 100], [-100, 100])
    plt.show()


def plot_metrics(metric_name, title, ylim=5):
    plt.title(title)
    plt.ylim(0, ylim)
    plt.plot(history.history[metric_name], color='blue', label=metric_name)
    plt.plot(history.history['val_' + metric_name], color='green', label='val_' + metric_name)
    plt.show()

# %% [markdown]
# ## Prepare the Data
#
# We download the dataset and format it for training.

# %%
# Get the data from UCI dataset
URL = 'https://archive.ics.uci.edu/ml/machine-learning-databases/00242/ENB2012_data.xlsx'

# Use pandas excel reader
df = pd.read_excel(URL)
df = df.sample(frac=1).reset_index(drop=True)

# Split the data into train and test with 80 train / 20 test
train, test = train_test_split(df, test_size=0.2)
train_stats = train.describe()

# Get Y1 and Y2 as the 2 outputs and format them as np arrays
train_stats.pop('Y1')
train_stats.pop('Y2')
train_stats = train_stats.transpose()
train_Y = format_output(train)
test_Y = format_output(test)

# Normalize the training and test data
norm_train_X = norm(train)
norm_test_X = norm(test)

# %% [markdown]
# ## Build the Model
#
# Here is how we'll build the model using the functional syntax. Notice that we can specify a list of outputs (i.e. `[y1_output, y2_output]`) when we instantiate the `Model()` class.

# %%
# Define model layers.
input_layer = Input(shape=(len(train .columns),))
first_dense = Dense(units='128', activation='relu')(input_layer)
second_dense = Dense(units='128', activation='relu')(first_dense)

# Y1 output will be fed directly from the second dense
y1_output = Dense(units='1', name='y1_output')(second_dense)
third_dense = Dense(units='64', activation='relu')(second_dense)

# Y2 output will come via the third dense
y2_output = Dense(units='1', name='y2_output')(third_dense)

# Define the model with the input layer and a list of output layers
model = Model(inputs=input_layer, outputs=[y1_output, y2_output])

print(model.summary())
# Out:
# Model: "model"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            [(None, 8)]          0
# __________________________________________________________________________________________________
# dense (Dense)                   (None, 128)          1152        input_1[0][0]
# __________________________________________________________________________________________________
# dense_1 (Dense)                 (None, 128)          16512       dense[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 64)           8256        dense_1[0][0]
# __________________________________________________________________________________________________
# y1_output (Dense)               (None, 1)            129         dense_1[0][0]
# __________________________________________________________________________________________________
# y2_output (Dense)               (None, 1)            65          dense_2[0][0]
# ==================================================================================================
# Total params: 26,114
# Trainable params: 26,114
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %% [markdown]
# ## Configure parameters
#
# We specify the optimizer as well as the loss and metrics for each output.

# %%
# Specify the optimizer, and compile the model with loss functions for both outputs
optimizer = tf.keras.optimizers.SGD(lr=0.001)
model.compile(optimizer=optimizer,
              loss={'y1_output': 'mse', 'y2_output': 'mse'},
              metrics={'y1_output': tf.keras.metrics.RootMeanSquaredError(),
                       'y2_output': tf.keras.metrics.RootMeanSquaredError()})

# %% [markdown]
# ## Train the Model

# %%
# Train the model for 500 epochs
history = model.fit(norm_train_X, train_Y,
                    epochs=500, batch_size=10, validation_data=(norm_test_X, test_Y))
# Out:
# Train on 614 samples, validate on 154 samples
# Epoch 1/500
# 614/614 [==============================] - 1s 900us/sample - loss: 243.9505 - y1_output_loss: 110.4680 - y2_output_loss: 131.3759 - y1_output_root_mean_squared_error: 10.5583 - y2_output_root_mean_squared_error: 11.5097 - val_loss: 37.4001 - val_y1_output_loss: 16.8269 - val_y2_output_loss: 19.7236 - val_y1_output_root_mean_squared_error: 4.1404 - val_y2_output_root_mean_squared_error: 4.5008
# Epoch 2/500
# 614/614 [==============================] - 0s 143us/sample - loss: 32.3912 - y1_output_loss: 13.0349 - y2_output_loss: 19.1827 - y1_output_root_mean_squared_error: 3.6226 - y2_output_root_mean_squared_error: 4.3895 - val_loss: 21.4652 - val_y1_output_loss: 10.1578 - val_y2_output_loss: 10.7051 - val_y1_output_root_mean_squared_error: 3.2368 - val_y2_output_root_mean_squared_error: 3.3148
# Epoch 3/500
# 614/614 [==============================] - 0s 131us/sample - loss: 24.1380 - y1_output_loss: 10.0035 - y2_output_loss: 14.0251 - y1_output_root_mean_squared_error: 3.1746 - y2_output_root_mean_squared_error: 3.7496 - val_loss: 18.8880 - val_y1_output_loss: 7.7930 - val_y2_output_loss: 11.1321 - val_y1_output_root_mean_squared_error: 2.8166 - val_y2_output_root_mean_squared_error: 3.3098
# Epoch 4/500
# 614/614 [==============================] - 0s 133us/sample - loss: 23.4985 - y1_output_loss: 9.7994 - y2_output_loss: 13.5453 - y1_output_root_mean_squared_error: 3.1376 - y2_output_root_mean_squared_error: 3.6951 - val_loss: 20.8870 - val_y1_output_loss: 8.3598 - val_y2_output_loss: 11.8853 - val_y1_output_root_mean_squared_error: 2.9281 - val_y2_output_root_mean_squared_error: 3.5090
# Epoch 5/500
# 614/614 [==============================] - 0s 146us/sample - loss: 29.0204 - y1_output_loss: 10.2458 - y2_output_loss: 18.5043 - y1_output_root_mean_squared_error: 3.2155 - y2_output_root_mean_squared_error: 4.3221 - val_loss: 20.0336 - val_y1_output_loss: 8.1532 - val_y2_output_loss: 11.3264 - val_y1_output_root_mean_squared_error: 2.8865 - val_y2_output_root_mean_squared_error: 3.4208
# Epoch 6/500
# 614/614 [==============================] - 0s 126us/sample - loss: 23.8566 - y1_output_loss: 9.5290 - y2_output_loss: 14.4809 - y1_output_root_mean_squared_error: 3.0710 - y2_output_root_mean_squared_error: 3.7981 - val_loss: 36.6586 - val_y1_output_loss: 10.9034 - val_y2_output_loss: 24.9762 - val_y1_output_root_mean_squared_error: 3.3209 - val_y2_output_root_mean_squared_error: 5.0626
# Epoch 7/500
# 614/614 [==============================] - 0s 124us/sample - loss: 22.3061 - y1_output_loss: 8.7713 - y2_output_loss: 13.5057 - y1_output_root_mean_squared_error: 2.9691 - y2_output_root_mean_squared_error: 3.6730 - val_loss: 21.5245 - val_y1_output_loss: 6.5418 - val_y2_output_loss: 15.0508 - val_y1_output_root_mean_squared_error: 2.6030 - val_y2_output_root_mean_squared_error: 3.8404
# Epoch 8/500
# 614/614 [==============================] - 0s 123us/sample - loss: 24.2658 - y1_output_loss: 8.8423 - y2_output_loss: 15.1992 - y1_output_root_mean_squared_error: 2.9868 - y2_output_root_mean_squared_error: 3.9173 - val_loss: 15.3580 - val_y1_output_loss: 6.6973 - val_y2_output_loss: 8.4223 - val_y1_output_root_mean_squared_error: 2.6144 - val_y2_output_root_mean_squared_error: 2.9194
# Epoch 9/500
# 614/614 [==============================] - 0s 121us/sample - loss: 22.2035 - y1_output_loss: 8.4943 - y2_output_loss: 13.5891 - y1_output_root_mean_squared_error: 2.9204 - y2_output_root_mean_squared_error: 3.6979 - val_loss: 15.3845 - val_y1_output_loss: 6.5713 - val_y2_output_loss: 8.4392 - val_y1_output_root_mean_squared_error: 2.6037 - val_y2_output_root_mean_squared_error: 2.9335
# Epoch 10/500
# 614/614 [==============================] - 0s 124us/sample - loss: 21.4291 - y1_output_loss: 8.1726 - y2_output_loss: 13.2642 - y1_output_root_mean_squared_error: 2.8485 - y2_output_root_mean_squared_error: 3.6490 - val_loss: 22.4257 - val_y1_output_loss: 9.5593 - val_y2_output_loss: 12.1796 - val_y1_output_root_mean_squared_error: 3.1328 - val_y2_output_root_mean_squared_error: 3.5512
# Epoch 11/500
# 614/614 [==============================] - 0s 132us/sample - loss: 20.7942 - y1_output_loss: 8.4940 - y2_output_loss: 12.5336 - y1_output_root_mean_squared_error: 2.8803 - y2_output_root_mean_squared_error: 3.5352 - val_loss: 21.4996 - val_y1_output_loss: 7.7734 - val_y2_output_loss: 14.2608 - val_y1_output_root_mean_squared_error: 2.7858 - val_y2_output_root_mean_squared_error: 3.7066
# Epoch 12/500
# 614/614 [==============================] - 0s 134us/sample - loss: 19.3290 - y1_output_loss: 7.6263 - y2_output_loss: 11.6534 - y1_output_root_mean_squared_error: 2.7653 - y2_output_root_mean_squared_error: 3.4179 - val_loss: 20.6373 - val_y1_output_loss: 9.0142 - val_y2_output_loss: 11.1644 - val_y1_output_root_mean_squared_error: 3.0200 - val_y2_output_root_mean_squared_error: 3.3937
# Epoch 13/500
# 614/614 [==============================] - 0s 131us/sample - loss: 21.5386 - y1_output_loss: 8.0400 - y2_output_loss: 13.3454 - y1_output_root_mean_squared_error: 2.8461 - y2_output_root_mean_squared_error: 3.6659 - val_loss: 17.1349 - val_y1_output_loss: 5.9519 - val_y2_output_loss: 11.1388 - val_y1_output_root_mean_squared_error: 2.4791 - val_y2_output_root_mean_squared_error: 3.3150
# Epoch 14/500
# 614/614 [==============================] - 0s 129us/sample - loss: 21.3513 - y1_output_loss: 8.1119 - y2_output_loss: 13.1913 - y1_output_root_mean_squared_error: 2.8383 - y2_output_root_mean_squared_error: 3.6463 - val_loss: 34.1984 - val_y1_output_loss: 11.8044 - val_y2_output_loss: 21.8243 - val_y1_output_root_mean_squared_error: 3.4442 - val_y2_output_root_mean_squared_error: 4.7261
# Epoch 15/500
# 614/614 [==============================] - 0s 125us/sample - loss: 20.5736 - y1_output_loss: 7.5823 - y2_output_loss: 12.9072 - y1_output_root_mean_squared_error: 2.7591 - y2_output_root_mean_squared_error: 3.6002 - val_loss: 34.5179 - val_y1_output_loss: 13.4609 - val_y2_output_loss: 20.6962 - val_y1_output_root_mean_squared_error: 3.6660 - val_y2_output_root_mean_squared_error: 4.5911
# Epoch 16/500
# 614/614 [==============================] - 0s 130us/sample - loss: 26.8451 - y1_output_loss: 8.8335 - y2_output_loss: 17.9796 - y1_output_root_mean_squared_error: 2.9810 - y2_output_root_mean_squared_error: 4.2378 - val_loss: 25.3685 - val_y1_output_loss: 7.1823 - val_y2_output_loss: 17.4884 - val_y1_output_root_mean_squared_error: 2.7021 - val_y2_output_root_mean_squared_error: 4.2505
# Epoch 17/500
# 614/614 [==============================] - 0s 126us/sample - loss: 19.3361 - y1_output_loss: 7.5783 - y2_output_loss: 11.7516 - y1_output_root_mean_squared_error: 2.7614 - y2_output_root_mean_squared_error: 3.4221 - val_loss: 15.7841 - val_y1_output_loss: 6.4773 - val_y2_output_loss: 9.0362 - val_y1_output_root_mean_squared_error: 2.5884 - val_y2_output_root_mean_squared_error: 3.0140
# Epoch 18/500
# 614/614 [==============================] - 0s 126us/sample - loss: 18.0727 - y1_output_loss: 7.1358 - y2_output_loss: 11.1926 - y1_output_root_mean_squared_error: 2.6686 - y2_output_root_mean_squared_error: 3.3092 - val_loss: 59.1137 - val_y1_output_loss: 10.1972 - val_y2_output_loss: 50.3136 - val_y1_output_root_mean_squared_error: 3.1934 - val_y2_output_root_mean_squared_error: 6.9940
# Epoch 19/500
# 614/614 [==============================] - 0s 124us/sample - loss: 18.4383 - y1_output_loss: 6.8492 - y2_output_loss: 11.4959 - y1_output_root_mean_squared_error: 2.6171 - y2_output_root_mean_squared_error: 3.4043 - val_loss: 26.9692 - val_y1_output_loss: 9.4794 - val_y2_output_loss: 17.0865 - val_y1_output_root_mean_squared_error: 3.0772 - val_y2_output_root_mean_squared_error: 4.1833
# Epoch 20/500
# 614/614 [==============================] - 0s 123us/sample - loss: 18.5634 - y1_output_loss: 6.8657 - y2_output_loss: 12.0004 - y1_output_root_mean_squared_error: 2.6141 - y2_output_root_mean_squared_error: 3.4249 - val_loss: 23.3261 - val_y1_output_loss: 8.7037 - val_y2_output_loss: 14.6325 - val_y1_output_root_mean_squared_error: 2.9747 - val_y2_output_root_mean_squared_error: 3.8049
# Epoch 21/500
# 614/614 [==============================] - 0s 131us/sample - loss: 16.3167 - y1_output_loss: 6.5805 - y2_output_loss: 9.9839 - y1_output_root_mean_squared_error: 2.5473 - y2_output_root_mean_squared_error: 3.1349 - val_loss: 24.6959 - val_y1_output_loss: 6.5527 - val_y2_output_loss: 18.5056 - val_y1_output_root_mean_squared_error: 2.5696 - val_y2_output_root_mean_squared_error: 4.2536
# Epoch 22/500
# 614/614 [==============================] - 0s 125us/sample - loss: 16.9614 - y1_output_loss: 6.2070 - y2_output_loss: 10.6256 - y1_output_root_mean_squared_error: 2.5018 - y2_output_root_mean_squared_error: 3.2715 - val_loss: 14.1028 - val_y1_output_loss: 5.8102 - val_y2_output_loss: 8.1917 - val_y1_output_root_mean_squared_error: 2.4260 - val_y2_output_root_mean_squared_error: 2.8666
# Epoch 23/500
# 614/614 [==============================] - 0s 125us/sample - loss: 16.5367 - y1_output_loss: 6.3995 - y2_output_loss: 10.0578 - y1_output_root_mean_squared_error: 2.5349 - y2_output_root_mean_squared_error: 3.1798 - val_loss: 13.6457 - val_y1_output_loss: 5.6706 - val_y2_output_loss: 7.7445 - val_y1_output_root_mean_squared_error: 2.3810 - val_y2_output_root_mean_squared_error: 2.8243
# Epoch 24/500
# 614/614 [==============================] - 0s 124us/sample - loss: 16.6390 - y1_output_loss: 6.3237 - y2_output_loss: 10.2519 - y1_output_root_mean_squared_error: 2.5221 - y2_output_root_mean_squared_error: 3.2059 - val_loss: 14.0385 - val_y1_output_loss: 5.6403 - val_y2_output_loss: 8.2533 - val_y1_output_root_mean_squared_error: 2.3972 - val_y2_output_root_mean_squared_error: 2.8796
# Epoch 25/500
# 614/614 [==============================] - 0s 123us/sample - loss: 18.6901 - y1_output_loss: 6.6262 - y2_output_loss: 12.1157 - y1_output_root_mean_squared_error: 2.5651 - y2_output_root_mean_squared_error: 3.4800 - val_loss: 12.7203 - val_y1_output_loss: 4.9265 - val_y2_output_loss: 7.6404 - val_y1_output_root_mean_squared_error: 2.2462 - val_y2_output_root_mean_squared_error: 2.7704
# Epoch 26/500
# 614/614 [==============================] - 0s 128us/sample - loss: 15.0143 - y1_output_loss: 5.5685 - y2_output_loss: 9.3188 - y1_output_root_mean_squared_error: 2.3695 - y2_output_root_mean_squared_error: 3.0659 - val_loss: 12.3340 - val_y1_output_loss: 5.4307 - val_y2_output_loss: 6.7435 - val_y1_output_root_mean_squared_error: 2.3297 - val_y2_output_root_mean_squared_error: 2.6280
# Epoch 27/500
# 614/614 [==============================] - 0s 131us/sample - loss: 12.2090 - y1_output_loss: 4.9456 - y2_output_loss: 7.4548 - y1_output_root_mean_squared_error: 2.2211 - y2_output_root_mean_squared_error: 2.6974 - val_loss: 37.8242 - val_y1_output_loss: 9.7209 - val_y2_output_loss: 28.6466 - val_y1_output_root_mean_squared_error: 3.1334 - val_y2_output_root_mean_squared_error: 5.2921
# Epoch 28/500
# 614/614 [==============================] - 0s 120us/sample - loss: 17.5261 - y1_output_loss: 5.8567 - y2_output_loss: 11.5132 - y1_output_root_mean_squared_error: 2.4303 - y2_output_root_mean_squared_error: 3.4088 - val_loss: 10.3723 - val_y1_output_loss: 3.9596 - val_y2_output_loss: 6.1171 - val_y1_output_root_mean_squared_error: 2.0190 - val_y2_output_root_mean_squared_error: 2.5091
# Epoch 29/500
# 614/614 [==============================] - 0s 122us/sample - loss: 14.9821 - y1_output_loss: 5.5291 - y2_output_loss: 9.4381 - y1_output_root_mean_squared_error: 2.3588 - y2_output_root_mean_squared_error: 3.0689 - val_loss: 10.3663 - val_y1_output_loss: 4.1083 - val_y2_output_loss: 6.1453 - val_y1_output_root_mean_squared_error: 2.0346 - val_y2_output_root_mean_squared_error: 2.4954
# Epoch 30/500
# 614/614 [==============================] - 0s 121us/sample - loss: 11.8958 - y1_output_loss: 4.4380 - y2_output_loss: 7.3629 - y1_output_root_mean_squared_error: 2.1150 - y2_output_root_mean_squared_error: 2.7244 - val_loss: 11.8618 - val_y1_output_loss: 4.4990 - val_y2_output_loss: 7.1998 - val_y1_output_root_mean_squared_error: 2.1112 - val_y2_output_root_mean_squared_error: 2.7211
# Epoch 31/500
# 614/614 [==============================] - 0s 131us/sample - loss: 12.8157 - y1_output_loss: 4.6256 - y2_output_loss: 8.0864 - y1_output_root_mean_squared_error: 2.1594 - y2_output_root_mean_squared_error: 2.8553 - val_loss: 9.4130 - val_y1_output_loss: 3.7278 - val_y2_output_loss: 5.4971 - val_y1_output_root_mean_squared_error: 1.9454 - val_y2_output_root_mean_squared_error: 2.3724
# Epoch 32/500
# 614/614 [==============================] - 0s 131us/sample - loss: 13.3044 - y1_output_loss: 4.7935 - y2_output_loss: 8.4541 - y1_output_root_mean_squared_error: 2.1959 - y2_output_root_mean_squared_error: 2.9124 - val_loss: 10.2775 - val_y1_output_loss: 4.3125 - val_y2_output_loss: 5.9191 - val_y1_output_root_mean_squared_error: 2.0577 - val_y2_output_root_mean_squared_error: 2.4583
# Epoch 33/500
# 614/614 [==============================] - 0s 122us/sample - loss: 11.8692 - y1_output_loss: 4.1704 - y2_output_loss: 7.7983 - y1_output_root_mean_squared_error: 2.0264 - y2_output_root_mean_squared_error: 2.7862 - val_loss: 32.2204 - val_y1_output_loss: 8.6447 - val_y2_output_loss: 23.7004 - val_y1_output_root_mean_squared_error: 2.9001 - val_y2_output_root_mean_squared_error: 4.8795
# Epoch 34/500
# 614/614 [==============================] - 0s 126us/sample - loss: 10.0318 - y1_output_loss: 3.7648 - y2_output_loss: 6.1973 - y1_output_root_mean_squared_error: 1.9438 - y2_output_root_mean_squared_error: 2.5007 - val_loss: 7.9819 - val_y1_output_loss: 3.0198 - val_y2_output_loss: 4.8268 - val_y1_output_root_mean_squared_error: 1.7463 - val_y2_output_root_mean_squared_error: 2.2209
# Epoch 35/500
# 614/614 [==============================] - 0s 125us/sample - loss: 11.0011 - y1_output_loss: 4.0929 - y2_output_loss: 6.9235 - y1_output_root_mean_squared_error: 2.0245 - y2_output_root_mean_squared_error: 2.6273 - val_loss: 9.8142 - val_y1_output_loss: 3.9164 - val_y2_output_loss: 5.7962 - val_y1_output_root_mean_squared_error: 1.9590 - val_y2_output_root_mean_squared_error: 2.4447
# Epoch 36/500
# 614/614 [==============================] - 0s 125us/sample - loss: 11.6824 - y1_output_loss: 4.0509 - y2_output_loss: 7.5649 - y1_output_root_mean_squared_error: 2.0143 - y2_output_root_mean_squared_error: 2.7613 - val_loss: 9.4175 - val_y1_output_loss: 3.5542 - val_y2_output_loss: 5.6782 - val_y1_output_root_mean_squared_error: 1.8985 - val_y2_output_root_mean_squared_error: 2.4111
# Epoch 37/500
# 614/614 [==============================] - 0s 129us/sample - loss: 10.6113 - y1_output_loss: 3.5276 - y2_output_loss: 7.1723 - y1_output_root_mean_squared_error: 1.8767 - y2_output_root_mean_squared_error: 2.6626 - val_loss: 9.3744 - val_y1_output_loss: 3.6058 - val_y2_output_loss: 5.6266 - val_y1_output_root_mean_squared_error: 1.9170 - val_y2_output_root_mean_squared_error: 2.3874
# Epoch 38/500
# 614/614 [==============================] - 0s 123us/sample - loss: 10.5295 - y1_output_loss: 3.7444 - y2_output_loss: 6.8121 - y1_output_root_mean_squared_error: 1.9385 - y2_output_root_mean_squared_error: 2.6022 - val_loss: 9.7455 - val_y1_output_loss: 3.9109 - val_y2_output_loss: 5.7160 - val_y1_output_root_mean_squared_error: 1.9600 - val_y2_output_root_mean_squared_error: 2.4298
# Epoch 39/500
# 614/614 [==============================] - 0s 131us/sample - loss: 10.2440 - y1_output_loss: 3.5624 - y2_output_loss: 6.5922 - y1_output_root_mean_squared_error: 1.8960 - y2_output_root_mean_squared_error: 2.5786 - val_loss: 7.7855 - val_y1_output_loss: 2.8917 - val_y2_output_loss: 4.7733 - val_y1_output_root_mean_squared_error: 1.6917 - val_y2_output_root_mean_squared_error: 2.2190
# Epoch 40/500
# 614/614 [==============================] - 0s 125us/sample - loss: 8.6293 - y1_output_loss: 3.0637 - y2_output_loss: 5.5023 - y1_output_root_mean_squared_error: 1.7545 - y2_output_root_mean_squared_error: 2.3561 - val_loss: 10.1231 - val_y1_output_loss: 3.9803 - val_y2_output_loss: 6.0750 - val_y1_output_root_mean_squared_error: 1.9750 - val_y2_output_root_mean_squared_error: 2.4945
# Epoch 41/500
# 614/614 [==============================] - 0s 128us/sample - loss: 9.2010 - y1_output_loss: 3.3801 - y2_output_loss: 5.8088 - y1_output_root_mean_squared_error: 1.8385 - y2_output_root_mean_squared_error: 2.4127 - val_loss: 10.4292 - val_y1_output_loss: 2.6694 - val_y2_output_loss: 7.5717 - val_y1_output_root_mean_squared_error: 1.6258 - val_y2_output_root_mean_squared_error: 2.7904
# Epoch 42/500
# 614/614 [==============================] - 0s 134us/sample - loss: 9.4389 - y1_output_loss: 3.0843 - y2_output_loss: 6.2963 - y1_output_root_mean_squared_error: 1.7638 - y2_output_root_mean_squared_error: 2.5155 - val_loss: 7.2454 - val_y1_output_loss: 2.5342 - val_y2_output_loss: 4.6098 - val_y1_output_root_mean_squared_error: 1.5865 - val_y2_output_root_mean_squared_error: 2.1745
# Epoch 43/500
# 614/614 [==============================] - 0s 128us/sample - loss: 7.6986 - y1_output_loss: 2.7659 - y2_output_loss: 4.9347 - y1_output_root_mean_squared_error: 1.6509 - y2_output_root_mean_squared_error: 2.2300 - val_loss: 11.0231 - val_y1_output_loss: 4.8554 - val_y2_output_loss: 6.0594 - val_y1_output_root_mean_squared_error: 2.1873 - val_y2_output_root_mean_squared_error: 2.4977
# Epoch 44/500
# 614/614 [==============================] - 0s 127us/sample - loss: 7.9548 - y1_output_loss: 2.8084 - y2_output_loss: 5.2947 - y1_output_root_mean_squared_error: 1.6688 - y2_output_root_mean_squared_error: 2.2737 - val_loss: 13.3448 - val_y1_output_loss: 2.6676 - val_y2_output_loss: 10.6862 - val_y1_output_root_mean_squared_error: 1.6381 - val_y2_output_root_mean_squared_error: 3.2652
# Epoch 45/500
# 614/614 [==============================] - 0s 125us/sample - loss: 7.1338 - y1_output_loss: 2.4575 - y2_output_loss: 4.6873 - y1_output_root_mean_squared_error: 1.5593 - y2_output_root_mean_squared_error: 2.1685 - val_loss: 13.1831 - val_y1_output_loss: 4.9741 - val_y2_output_loss: 8.1486 - val_y1_output_root_mean_squared_error: 2.1997 - val_y2_output_root_mean_squared_error: 2.8886
# Epoch 46/500
# 614/614 [==============================] - 0s 132us/sample - loss: 7.9436 - y1_output_loss: 2.4848 - y2_output_loss: 5.4114 - y1_output_root_mean_squared_error: 1.5780 - y2_output_root_mean_squared_error: 2.3352 - val_loss: 6.2119 - val_y1_output_loss: 2.0560 - val_y2_output_loss: 4.0354 - val_y1_output_root_mean_squared_error: 1.4350 - val_y2_output_root_mean_squared_error: 2.0378
# Epoch 47/500
# 614/614 [==============================] - 0s 130us/sample - loss: 7.8258 - y1_output_loss: 2.5457 - y2_output_loss: 5.2549 - y1_output_root_mean_squared_error: 1.5984 - y2_output_root_mean_squared_error: 2.2959 - val_loss: 11.8595 - val_y1_output_loss: 2.6066 - val_y2_output_loss: 9.2359 - val_y1_output_root_mean_squared_error: 1.6378 - val_y2_output_root_mean_squared_error: 3.0294
# Epoch 48/500
# 614/614 [==============================] - 0s 133us/sample - loss: 7.3130 - y1_output_loss: 2.3489 - y2_output_loss: 4.9676 - y1_output_root_mean_squared_error: 1.5199 - y2_output_root_mean_squared_error: 2.2367 - val_loss: 6.2997 - val_y1_output_loss: 2.1918 - val_y2_output_loss: 4.0231 - val_y1_output_root_mean_squared_error: 1.4715 - val_y2_output_root_mean_squared_error: 2.0333
# Epoch 49/500
# 614/614 [==============================] - 0s 128us/sample - loss: 6.7144 - y1_output_loss: 2.0173 - y2_output_loss: 4.6710 - y1_output_root_mean_squared_error: 1.4151 - y2_output_root_mean_squared_error: 2.1707 - val_loss: 8.4620 - val_y1_output_loss: 3.1281 - val_y2_output_loss: 5.3715 - val_y1_output_root_mean_squared_error: 1.7401 - val_y2_output_root_mean_squared_error: 2.3311
# Epoch 50/500
# 614/614 [==============================] - 0s 137us/sample - loss: 6.8112 - y1_output_loss: 2.3059 - y2_output_loss: 4.4452 - y1_output_root_mean_squared_error: 1.5243 - y2_output_root_mean_squared_error: 2.1184 - val_loss: 5.9118 - val_y1_output_loss: 1.9700 - val_y2_output_loss: 3.8281 - val_y1_output_root_mean_squared_error: 1.4064 - val_y2_output_root_mean_squared_error: 1.9834
# Epoch 51/500
# 614/614 [==============================] - 0s 134us/sample - loss: 6.4407 - y1_output_loss: 2.0319 - y2_output_loss: 4.4600 - y1_output_root_mean_squared_error: 1.4281 - y2_output_root_mean_squared_error: 2.0979 - val_loss: 6.0530 - val_y1_output_loss: 1.7709 - val_y2_output_loss: 4.1668 - val_y1_output_root_mean_squared_error: 1.3445 - val_y2_output_root_mean_squared_error: 2.0605
# Epoch 52/500
# 614/614 [==============================] - 0s 134us/sample - loss: 8.9693 - y1_output_loss: 2.8106 - y2_output_loss: 6.1184 - y1_output_root_mean_squared_error: 1.6746 - y2_output_root_mean_squared_error: 2.4829 - val_loss: 5.9920 - val_y1_output_loss: 1.8837 - val_y2_output_loss: 4.0110 - val_y1_output_root_mean_squared_error: 1.3840 - val_y2_output_root_mean_squared_error: 2.0190
# Epoch 53/500
# 614/614 [==============================] - 0s 133us/sample - loss: 6.2208 - y1_output_loss: 1.8696 - y2_output_loss: 4.2940 - y1_output_root_mean_squared_error: 1.3736 - y2_output_root_mean_squared_error: 2.0818 - val_loss: 5.6241 - val_y1_output_loss: 1.6723 - val_y2_output_loss: 3.8305 - val_y1_output_root_mean_squared_error: 1.2949 - val_y2_output_root_mean_squared_error: 1.9868
# Epoch 54/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.4265 - y1_output_loss: 1.7149 - y2_output_loss: 3.7748 - y1_output_root_mean_squared_error: 1.3142 - y2_output_root_mean_squared_error: 1.9234 - val_loss: 8.7598 - val_y1_output_loss: 2.8916 - val_y2_output_loss: 5.7669 - val_y1_output_root_mean_squared_error: 1.6851 - val_y2_output_root_mean_squared_error: 2.4331
# Epoch 55/500
# 614/614 [==============================] - 0s 134us/sample - loss: 6.9286 - y1_output_loss: 2.0609 - y2_output_loss: 4.8270 - y1_output_root_mean_squared_error: 1.4348 - y2_output_root_mean_squared_error: 2.2068 - val_loss: 5.3607 - val_y1_output_loss: 1.6562 - val_y2_output_loss: 3.6077 - val_y1_output_root_mean_squared_error: 1.2906 - val_y2_output_root_mean_squared_error: 1.9223
# Epoch 56/500
# 614/614 [==============================] - 0s 128us/sample - loss: 5.9816 - y1_output_loss: 1.7968 - y2_output_loss: 4.2818 - y1_output_root_mean_squared_error: 1.3260 - y2_output_root_mean_squared_error: 2.0551 - val_loss: 5.0557 - val_y1_output_loss: 1.3653 - val_y2_output_loss: 3.6329 - val_y1_output_root_mean_squared_error: 1.1694 - val_y2_output_root_mean_squared_error: 1.9205
# Epoch 57/500
# 614/614 [==============================] - 0s 132us/sample - loss: 6.0305 - y1_output_loss: 2.1181 - y2_output_loss: 3.8883 - y1_output_root_mean_squared_error: 1.4567 - y2_output_root_mean_squared_error: 1.9770 - val_loss: 6.2949 - val_y1_output_loss: 1.9261 - val_y2_output_loss: 4.3699 - val_y1_output_root_mean_squared_error: 1.3818 - val_y2_output_root_mean_squared_error: 2.0942
# Epoch 58/500
# 614/614 [==============================] - 0s 126us/sample - loss: 5.9353 - y1_output_loss: 1.7763 - y2_output_loss: 4.1952 - y1_output_root_mean_squared_error: 1.3214 - y2_output_root_mean_squared_error: 2.0468 - val_loss: 6.2540 - val_y1_output_loss: 2.1420 - val_y2_output_loss: 4.0332 - val_y1_output_root_mean_squared_error: 1.4403 - val_y2_output_root_mean_squared_error: 2.0444
# Epoch 59/500
# 614/614 [==============================] - 0s 137us/sample - loss: 8.8329 - y1_output_loss: 2.4300 - y2_output_loss: 6.3904 - y1_output_root_mean_squared_error: 1.5525 - y2_output_root_mean_squared_error: 2.5343 - val_loss: 7.9191 - val_y1_output_loss: 2.2715 - val_y2_output_loss: 5.7257 - val_y1_output_root_mean_squared_error: 1.5111 - val_y2_output_root_mean_squared_error: 2.3739
# Epoch 60/500
# 614/614 [==============================] - 0s 137us/sample - loss: 5.3256 - y1_output_loss: 1.6187 - y2_output_loss: 3.6691 - y1_output_root_mean_squared_error: 1.2753 - y2_output_root_mean_squared_error: 1.9233 - val_loss: 4.8397 - val_y1_output_loss: 1.4790 - val_y2_output_loss: 3.3253 - val_y1_output_root_mean_squared_error: 1.2093 - val_y2_output_root_mean_squared_error: 1.8377
# Epoch 61/500
# 614/614 [==============================] - 0s 136us/sample - loss: 5.5515 - y1_output_loss: 1.5874 - y2_output_loss: 4.0050 - y1_output_root_mean_squared_error: 1.2640 - y2_output_root_mean_squared_error: 1.9884 - val_loss: 7.2109 - val_y1_output_loss: 1.5656 - val_y2_output_loss: 5.6603 - val_y1_output_root_mean_squared_error: 1.2648 - val_y2_output_root_mean_squared_error: 2.3688
# Epoch 62/500
# 614/614 [==============================] - 0s 136us/sample - loss: 5.8895 - y1_output_loss: 1.4632 - y2_output_loss: 4.4968 - y1_output_root_mean_squared_error: 1.2150 - y2_output_root_mean_squared_error: 2.1008 - val_loss: 11.6821 - val_y1_output_loss: 2.1207 - val_y2_output_loss: 9.4748 - val_y1_output_root_mean_squared_error: 1.4461 - val_y2_output_root_mean_squared_error: 3.0969
# Epoch 63/500
# 614/614 [==============================] - 0s 138us/sample - loss: 4.9830 - y1_output_loss: 1.4514 - y2_output_loss: 3.5710 - y1_output_root_mean_squared_error: 1.2078 - y2_output_root_mean_squared_error: 1.8773 - val_loss: 15.4028 - val_y1_output_loss: 2.5832 - val_y2_output_loss: 12.7683 - val_y1_output_root_mean_squared_error: 1.5742 - val_y2_output_root_mean_squared_error: 3.5951
# Epoch 64/500
# 614/614 [==============================] - 0s 132us/sample - loss: 5.0928 - y1_output_loss: 1.4582 - y2_output_loss: 3.6112 - y1_output_root_mean_squared_error: 1.2088 - y2_output_root_mean_squared_error: 1.9057 - val_loss: 4.2831 - val_y1_output_loss: 1.3227 - val_y2_output_loss: 2.9056 - val_y1_output_root_mean_squared_error: 1.1489 - val_y2_output_root_mean_squared_error: 1.7214
# Epoch 65/500
# 614/614 [==============================] - 0s 135us/sample - loss: 5.2830 - y1_output_loss: 1.5010 - y2_output_loss: 3.7564 - y1_output_root_mean_squared_error: 1.2219 - y2_output_root_mean_squared_error: 1.9468 - val_loss: 4.5524 - val_y1_output_loss: 1.1854 - val_y2_output_loss: 3.3193 - val_y1_output_root_mean_squared_error: 1.1036 - val_y2_output_root_mean_squared_error: 1.8261
# Epoch 66/500
# 614/614 [==============================] - 0s 133us/sample - loss: 4.4466 - y1_output_loss: 1.1669 - y2_output_loss: 3.3052 - y1_output_root_mean_squared_error: 1.0773 - y2_output_root_mean_squared_error: 1.8128 - val_loss: 10.3720 - val_y1_output_loss: 4.1708 - val_y2_output_loss: 6.1600 - val_y1_output_root_mean_squared_error: 2.0034 - val_y2_output_root_mean_squared_error: 2.5216
# Epoch 67/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.9224 - y1_output_loss: 1.3549 - y2_output_loss: 3.5253 - y1_output_root_mean_squared_error: 1.1687 - y2_output_root_mean_squared_error: 1.8859 - val_loss: 4.0950 - val_y1_output_loss: 1.1108 - val_y2_output_loss: 2.9526 - val_y1_output_root_mean_squared_error: 1.0481 - val_y2_output_root_mean_squared_error: 1.7310
# Epoch 68/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.8076 - y1_output_loss: 1.1536 - y2_output_loss: 3.6501 - y1_output_root_mean_squared_error: 1.0751 - y2_output_root_mean_squared_error: 1.9109 - val_loss: 5.5721 - val_y1_output_loss: 1.0574 - val_y2_output_loss: 4.5762 - val_y1_output_root_mean_squared_error: 1.0382 - val_y2_output_root_mean_squared_error: 2.1200
# Epoch 69/500
# 614/614 [==============================] - 0s 126us/sample - loss: 4.5047 - y1_output_loss: 1.1508 - y2_output_loss: 3.3341 - y1_output_root_mean_squared_error: 1.0732 - y2_output_root_mean_squared_error: 1.8311 - val_loss: 6.8487 - val_y1_output_loss: 1.8596 - val_y2_output_loss: 4.8972 - val_y1_output_root_mean_squared_error: 1.3443 - val_y2_output_root_mean_squared_error: 2.2453
# Epoch 70/500
# 614/614 [==============================] - 0s 128us/sample - loss: 5.1105 - y1_output_loss: 1.2080 - y2_output_loss: 3.9083 - y1_output_root_mean_squared_error: 1.1023 - y2_output_root_mean_squared_error: 1.9737 - val_loss: 4.3504 - val_y1_output_loss: 0.8594 - val_y2_output_loss: 3.5329 - val_y1_output_root_mean_squared_error: 0.9331 - val_y2_output_root_mean_squared_error: 1.8654
# Epoch 71/500
# 614/614 [==============================] - 0s 124us/sample - loss: 4.0851 - y1_output_loss: 1.0659 - y2_output_loss: 3.0003 - y1_output_root_mean_squared_error: 1.0321 - y2_output_root_mean_squared_error: 1.7378 - val_loss: 4.8778 - val_y1_output_loss: 1.2873 - val_y2_output_loss: 3.5487 - val_y1_output_root_mean_squared_error: 1.1276 - val_y2_output_root_mean_squared_error: 1.8990
# Epoch 72/500
# 614/614 [==============================] - 0s 124us/sample - loss: 4.7448 - y1_output_loss: 1.1393 - y2_output_loss: 3.6268 - y1_output_root_mean_squared_error: 1.0700 - y2_output_root_mean_squared_error: 1.8973 - val_loss: 7.9852 - val_y1_output_loss: 1.7227 - val_y2_output_loss: 6.4983 - val_y1_output_root_mean_squared_error: 1.3149 - val_y2_output_root_mean_squared_error: 2.5012
# Epoch 73/500
# 614/614 [==============================] - 0s 124us/sample - loss: 4.2112 - y1_output_loss: 1.0293 - y2_output_loss: 3.1824 - y1_output_root_mean_squared_error: 1.0162 - y2_output_root_mean_squared_error: 1.7829 - val_loss: 6.0077 - val_y1_output_loss: 1.8471 - val_y2_output_loss: 4.1883 - val_y1_output_root_mean_squared_error: 1.3356 - val_y2_output_root_mean_squared_error: 2.0552
# Epoch 74/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.8953 - y1_output_loss: 0.8951 - y2_output_loss: 3.1229 - y1_output_root_mean_squared_error: 0.9482 - y2_output_root_mean_squared_error: 1.7309 - val_loss: 22.4010 - val_y1_output_loss: 2.9084 - val_y2_output_loss: 19.9517 - val_y1_output_root_mean_squared_error: 1.7222 - val_y2_output_root_mean_squared_error: 4.4085
# Epoch 75/500
# 614/614 [==============================] - 0s 134us/sample - loss: 4.2867 - y1_output_loss: 1.0800 - y2_output_loss: 3.2233 - y1_output_root_mean_squared_error: 1.0318 - y2_output_root_mean_squared_error: 1.7950 - val_loss: 4.7093 - val_y1_output_loss: 1.5848 - val_y2_output_loss: 3.1315 - val_y1_output_root_mean_squared_error: 1.2624 - val_y2_output_root_mean_squared_error: 1.7651
# Epoch 76/500
# 614/614 [==============================] - 0s 125us/sample - loss: 4.0403 - y1_output_loss: 0.9627 - y2_output_loss: 3.1080 - y1_output_root_mean_squared_error: 0.9784 - y2_output_root_mean_squared_error: 1.7559 - val_loss: 7.8371 - val_y1_output_loss: 1.6627 - val_y2_output_loss: 6.1033 - val_y1_output_root_mean_squared_error: 1.2702 - val_y2_output_root_mean_squared_error: 2.4948
# Epoch 77/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.5189 - y1_output_loss: 0.8153 - y2_output_loss: 2.6781 - y1_output_root_mean_squared_error: 0.9035 - y2_output_root_mean_squared_error: 1.6439 - val_loss: 5.1951 - val_y1_output_loss: 1.1486 - val_y2_output_loss: 4.1485 - val_y1_output_root_mean_squared_error: 1.0829 - val_y2_output_root_mean_squared_error: 2.0056
# Epoch 78/500
# 614/614 [==============================] - 0s 131us/sample - loss: 3.3331 - y1_output_loss: 0.7703 - y2_output_loss: 2.5734 - y1_output_root_mean_squared_error: 0.8655 - y2_output_root_mean_squared_error: 1.6075 - val_loss: 3.5426 - val_y1_output_loss: 0.8978 - val_y2_output_loss: 2.6095 - val_y1_output_root_mean_squared_error: 0.9410 - val_y2_output_root_mean_squared_error: 1.6301
# Epoch 79/500
# 614/614 [==============================] - 0s 125us/sample - loss: 3.4839 - y1_output_loss: 0.6882 - y2_output_loss: 2.7895 - y1_output_root_mean_squared_error: 0.8280 - y2_output_root_mean_squared_error: 1.6728 - val_loss: 4.2319 - val_y1_output_loss: 0.8270 - val_y2_output_loss: 3.5209 - val_y1_output_root_mean_squared_error: 0.9145 - val_y2_output_root_mean_squared_error: 1.8427
# Epoch 80/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.6697 - y1_output_loss: 0.8077 - y2_output_loss: 2.8488 - y1_output_root_mean_squared_error: 0.9017 - y2_output_root_mean_squared_error: 1.6901 - val_loss: 4.8999 - val_y1_output_loss: 0.8439 - val_y2_output_loss: 3.9433 - val_y1_output_root_mean_squared_error: 0.9164 - val_y2_output_root_mean_squared_error: 2.0150
# Epoch 81/500
# 614/614 [==============================] - 0s 128us/sample - loss: 3.9567 - y1_output_loss: 0.8653 - y2_output_loss: 3.0750 - y1_output_root_mean_squared_error: 0.9342 - y2_output_root_mean_squared_error: 1.7561 - val_loss: 4.0290 - val_y1_output_loss: 0.9808 - val_y2_output_loss: 3.0915 - val_y1_output_root_mean_squared_error: 0.9860 - val_y2_output_root_mean_squared_error: 1.7484
# Epoch 82/500
# 614/614 [==============================] - 0s 126us/sample - loss: 3.5211 - y1_output_loss: 0.7217 - y2_output_loss: 2.7744 - y1_output_root_mean_squared_error: 0.8516 - y2_output_root_mean_squared_error: 1.6721 - val_loss: 3.3246 - val_y1_output_loss: 0.6056 - val_y2_output_loss: 2.7754 - val_y1_output_root_mean_squared_error: 0.7772 - val_y2_output_root_mean_squared_error: 1.6494
# Epoch 83/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.9315 - y1_output_loss: 0.8785 - y2_output_loss: 3.0716 - y1_output_root_mean_squared_error: 0.9350 - y2_output_root_mean_squared_error: 1.7485 - val_loss: 7.9250 - val_y1_output_loss: 2.6866 - val_y2_output_loss: 5.1198 - val_y1_output_root_mean_squared_error: 1.6258 - val_y2_output_root_mean_squared_error: 2.2982
# Epoch 84/500
# 614/614 [==============================] - 0s 133us/sample - loss: 3.4015 - y1_output_loss: 0.6761 - y2_output_loss: 2.6991 - y1_output_root_mean_squared_error: 0.8245 - y2_output_root_mean_squared_error: 1.6497 - val_loss: 3.5297 - val_y1_output_loss: 0.8882 - val_y2_output_loss: 2.5839 - val_y1_output_root_mean_squared_error: 0.9380 - val_y2_output_root_mean_squared_error: 1.6278
# Epoch 85/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.3525 - y1_output_loss: 0.6780 - y2_output_loss: 2.6899 - y1_output_root_mean_squared_error: 0.8255 - y2_output_root_mean_squared_error: 1.6344 - val_loss: 4.5619 - val_y1_output_loss: 1.3800 - val_y2_output_loss: 3.2240 - val_y1_output_root_mean_squared_error: 1.1769 - val_y2_output_root_mean_squared_error: 1.7824
# Epoch 86/500
# 614/614 [==============================] - 0s 136us/sample - loss: 3.7612 - y1_output_loss: 0.8022 - y2_output_loss: 2.9514 - y1_output_root_mean_squared_error: 0.8927 - y2_output_root_mean_squared_error: 1.7217 - val_loss: 2.7821 - val_y1_output_loss: 0.5969 - val_y2_output_loss: 2.2166 - val_y1_output_root_mean_squared_error: 0.7816 - val_y2_output_root_mean_squared_error: 1.4735
# Epoch 87/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.7873 - y1_output_loss: 0.9002 - y2_output_loss: 2.8579 - y1_output_root_mean_squared_error: 0.9528 - y2_output_root_mean_squared_error: 1.6969 - val_loss: 2.8683 - val_y1_output_loss: 0.5577 - val_y2_output_loss: 2.3232 - val_y1_output_root_mean_squared_error: 0.7526 - val_y2_output_root_mean_squared_error: 1.5172
# Epoch 88/500
# 614/614 [==============================] - 0s 135us/sample - loss: 2.9303 - y1_output_loss: 0.5876 - y2_output_loss: 2.3293 - y1_output_root_mean_squared_error: 0.7690 - y2_output_root_mean_squared_error: 1.5293 - val_loss: 3.6789 - val_y1_output_loss: 0.6224 - val_y2_output_loss: 3.1355 - val_y1_output_root_mean_squared_error: 0.7932 - val_y2_output_root_mean_squared_error: 1.7464
# Epoch 89/500
# 614/614 [==============================] - 0s 135us/sample - loss: 3.1180 - y1_output_loss: 0.5778 - y2_output_loss: 2.5255 - y1_output_root_mean_squared_error: 0.7620 - y2_output_root_mean_squared_error: 1.5929 - val_loss: 11.1111 - val_y1_output_loss: 0.9607 - val_y2_output_loss: 10.5429 - val_y1_output_root_mean_squared_error: 0.9917 - val_y2_output_root_mean_squared_error: 3.1824
# Epoch 90/500
# 614/614 [==============================] - 0s 132us/sample - loss: 3.3433 - y1_output_loss: 0.6528 - y2_output_loss: 2.6605 - y1_output_root_mean_squared_error: 0.8115 - y2_output_root_mean_squared_error: 1.6385 - val_loss: 2.9461 - val_y1_output_loss: 0.5660 - val_y2_output_loss: 2.3934 - val_y1_output_root_mean_squared_error: 0.7547 - val_y2_output_root_mean_squared_error: 1.5416
# Epoch 91/500
# 614/614 [==============================] - 0s 125us/sample - loss: 2.9897 - y1_output_loss: 0.5736 - y2_output_loss: 2.4022 - y1_output_root_mean_squared_error: 0.7597 - y2_output_root_mean_squared_error: 1.5532 - val_loss: 2.8446 - val_y1_output_loss: 0.6570 - val_y2_output_loss: 2.2149 - val_y1_output_root_mean_squared_error: 0.8136 - val_y2_output_root_mean_squared_error: 1.4774
# Epoch 92/500
# 614/614 [==============================] - 0s 134us/sample - loss: 3.6167 - y1_output_loss: 0.6887 - y2_output_loss: 2.9257 - y1_output_root_mean_squared_error: 0.8303 - y2_output_root_mean_squared_error: 1.7110 - val_loss: 4.4095 - val_y1_output_loss: 1.5642 - val_y2_output_loss: 2.8773 - val_y1_output_root_mean_squared_error: 1.2408 - val_y2_output_root_mean_squared_error: 1.6941
# Epoch 93/500
# 614/614 [==============================] - 0s 132us/sample - loss: 4.4986 - y1_output_loss: 0.7639 - y2_output_loss: 3.6959 - y1_output_root_mean_squared_error: 0.8775 - y2_output_root_mean_squared_error: 1.9310 - val_loss: 3.0819 - val_y1_output_loss: 0.6483 - val_y2_output_loss: 2.5634 - val_y1_output_root_mean_squared_error: 0.8098 - val_y2_output_root_mean_squared_error: 1.5576
# Epoch 94/500
# 614/614 [==============================] - 0s 127us/sample - loss: 3.0726 - y1_output_loss: 0.6651 - y2_output_loss: 2.4166 - y1_output_root_mean_squared_error: 0.8181 - y2_output_root_mean_squared_error: 1.5503 - val_loss: 4.0173 - val_y1_output_loss: 0.8193 - val_y2_output_loss: 3.1410 - val_y1_output_root_mean_squared_error: 0.9002 - val_y2_output_root_mean_squared_error: 1.7908
# Epoch 95/500
# 614/614 [==============================] - 0s 124us/sample - loss: 2.8235 - y1_output_loss: 0.5773 - y2_output_loss: 2.2360 - y1_output_root_mean_squared_error: 0.7606 - y2_output_root_mean_squared_error: 1.4984 - val_loss: 5.3252 - val_y1_output_loss: 0.8344 - val_y2_output_loss: 4.6727 - val_y1_output_root_mean_squared_error: 0.9282 - val_y2_output_root_mean_squared_error: 2.1127
# Epoch 96/500
# 614/614 [==============================] - 0s 125us/sample - loss: 2.7774 - y1_output_loss: 0.6019 - y2_output_loss: 2.1654 - y1_output_root_mean_squared_error: 0.7731 - y2_output_root_mean_squared_error: 1.4764 - val_loss: 3.6978 - val_y1_output_loss: 0.7134 - val_y2_output_loss: 3.1324 - val_y1_output_root_mean_squared_error: 0.8555 - val_y2_output_root_mean_squared_error: 1.7222
# Epoch 97/500
# 614/614 [==============================] - 0s 124us/sample - loss: 3.8421 - y1_output_loss: 0.7642 - y2_output_loss: 3.1421 - y1_output_root_mean_squared_error: 0.8739 - y2_output_root_mean_squared_error: 1.7546 - val_loss: 9.7565 - val_y1_output_loss: 2.8055 - val_y2_output_loss: 6.8061 - val_y1_output_root_mean_squared_error: 1.6519 - val_y2_output_root_mean_squared_error: 2.6510
# Epoch 98/500
# 614/614 [==============================] - 0s 125us/sample - loss: 3.4079 - y1_output_loss: 0.8319 - y2_output_loss: 2.5459 - y1_output_root_mean_squared_error: 0.9159 - y2_output_root_mean_squared_error: 1.6028 - val_loss: 2.7077 - val_y1_output_loss: 0.4950 - val_y2_output_loss: 2.2396 - val_y1_output_root_mean_squared_error: 0.7105 - val_y2_output_root_mean_squared_error: 1.4842
# Epoch 99/500
# 614/614 [==============================] - 0s 124us/sample - loss: 3.6171 - y1_output_loss: 0.7495 - y2_output_loss: 2.8528 - y1_output_root_mean_squared_error: 0.8682 - y2_output_root_mean_squared_error: 1.6921 - val_loss: 3.5552 - val_y1_output_loss: 0.5697 - val_y2_output_loss: 3.1081 - val_y1_output_root_mean_squared_error: 0.7560 - val_y2_output_root_mean_squared_error: 1.7273
# Epoch 100/500
# 614/614 [==============================] - 0s 123us/sample - loss: 3.2533 - y1_output_loss: 0.7949 - y2_output_loss: 2.4428 - y1_output_root_mean_squared_error: 0.8948 - y2_output_root_mean_squared_error: 1.5661 - val_loss: 2.6740 - val_y1_output_loss: 0.5411 - val_y2_output_loss: 2.1687 - val_y1_output_root_mean_squared_error: 0.7321 - val_y2_output_root_mean_squared_error: 1.4622
# Epoch 101/500
# 614/614 [==============================] - 0s 124us/sample - loss: 2.5377 - y1_output_loss: 0.4649 - y2_output_loss: 2.0577 - y1_output_root_mean_squared_error: 0.6837 - y2_output_root_mean_squared_error: 1.4388 - val_loss: 4.2046 - val_y1_output_loss: 0.8848 - val_y2_output_loss: 3.2483 - val_y1_output_root_mean_squared_error: 0.9345 - val_y2_output_root_mean_squared_error: 1.8252
# Epoch 102/500
# 614/614 [==============================] - 0s 124us/sample - loss: 2.5868 - y1_output_loss: 0.4713 - y2_output_loss: 2.1022 - y1_output_root_mean_squared_error: 0.6893 - y2_output_root_mean_squared_error: 1.4531 - val_loss: 3.3665 - val_y1_output_loss: 0.6714 - val_y2_output_loss: 2.7190 - val_y1_output_root_mean_squared_error: 0.8263 - val_y2_output_root_mean_squared_error: 1.6382
# Epoch 103/500
# 614/614 [==============================] - 0s 124us/sample - loss: 2.6889 - y1_output_loss: 0.5754 - y2_output_loss: 2.1004 - y1_output_root_mean_squared_error: 0.7564 - y2_output_root_mean_squared_error: 1.4549 - val_loss: 2.6887 - val_y1_output_loss: 0.5753 - val_y2_output_loss: 2.1365 - val_y1_output_root_mean_squared_error: 0.7560 - val_y2_output_root_mean_squared_error: 1.4551
# Epoch 104/500
# 614/614 [==============================] - 0s 123us/sample - loss: 2.5825 - y1_output_loss: 0.5192 - y2_output_loss: 2.0391 - y1_output_root_mean_squared_error: 0.7239 - y2_output_root_mean_squared_error: 1.4347 - val_loss: 2.5327 - val_y1_output_loss: 0.5600 - val_y2_output_loss: 1.9885 - val_y1_output_root_mean_squared_error: 0.7420 - val_y2_output_root_mean_squared_error: 1.4079
# Epoch 105/500
# 614/614 [==============================] - 0s 123us/sample - loss: 3.0352 - y1_output_loss: 0.5283 - y2_output_loss: 2.4857 - y1_output_root_mean_squared_error: 0.7275 - y2_output_root_mean_squared_error: 1.5830 - val_loss: 2.4609 - val_y1_output_loss: 0.4508 - val_y2_output_loss: 2.0492 - val_y1_output_root_mean_squared_error: 0.6787 - val_y2_output_root_mean_squared_error: 1.4143
# Epoch 106/500
# 614/614 [==============================] - 0s 124us/sample - loss: 3.5420 - y1_output_loss: 0.7375 - y2_output_loss: 2.8046 - y1_output_root_mean_squared_error: 0.8593 - y2_output_root_mean_squared_error: 1.6744 - val_loss: 3.6460 - val_y1_output_loss: 0.8485 - val_y2_output_loss: 2.9033 - val_y1_output_root_mean_squared_error: 0.9343 - val_y2_output_root_mean_squared_error: 1.6652
# Epoch 107/500
# 614/614 [==============================] - 0s 123us/sample - loss: 2.8136 - y1_output_loss: 0.6060 - y2_output_loss: 2.1961 - y1_output_root_mean_squared_error: 0.7780 - y2_output_root_mean_squared_error: 1.4860 - val_loss: 3.2098 - val_y1_output_loss: 0.6834 - val_y2_output_loss: 2.6236 - val_y1_output_root_mean_squared_error: 0.8377 - val_y2_output_root_mean_squared_error: 1.5837
# Epoch 108/500
# 614/614 [==============================] - 0s 122us/sample - loss: 2.4840 - y1_output_loss: 0.5264 - y2_output_loss: 1.9597 - y1_output_root_mean_squared_error: 0.7237 - y2_output_root_mean_squared_error: 1.4001 - val_loss: 4.8105 - val_y1_output_loss: 0.9697 - val_y2_output_loss: 4.0650 - val_y1_output_root_mean_squared_error: 0.9894 - val_y2_output_root_mean_squared_error: 1.9575
# Epoch 109/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.6965 - y1_output_loss: 0.5345 - y2_output_loss: 2.2132 - y1_output_root_mean_squared_error: 0.7316 - y2_output_root_mean_squared_error: 1.4701 - val_loss: 5.0221 - val_y1_output_loss: 1.0247 - val_y2_output_loss: 4.0742 - val_y1_output_root_mean_squared_error: 0.9817 - val_y2_output_root_mean_squared_error: 2.0146
# Epoch 110/500
# 614/614 [==============================] - 0s 123us/sample - loss: 2.4230 - y1_output_loss: 0.4431 - y2_output_loss: 2.0403 - y1_output_root_mean_squared_error: 0.6618 - y2_output_root_mean_squared_error: 1.4089 - val_loss: 14.0655 - val_y1_output_loss: 4.1801 - val_y2_output_loss: 10.0570 - val_y1_output_root_mean_squared_error: 2.0030 - val_y2_output_root_mean_squared_error: 3.1707
# Epoch 111/500
# 614/614 [==============================] - 0s 124us/sample - loss: 2.4440 - y1_output_loss: 0.5251 - y2_output_loss: 1.9007 - y1_output_root_mean_squared_error: 0.7273 - y2_output_root_mean_squared_error: 1.3838 - val_loss: 4.2779 - val_y1_output_loss: 1.7330 - val_y2_output_loss: 2.5154 - val_y1_output_root_mean_squared_error: 1.2958 - val_y2_output_root_mean_squared_error: 1.6121
# Epoch 112/500
# 614/614 [==============================] - 0s 130us/sample - loss: 2.6242 - y1_output_loss: 0.5501 - y2_output_loss: 2.0585 - y1_output_root_mean_squared_error: 0.7424 - y2_output_root_mean_squared_error: 1.4398 - val_loss: 2.4440 - val_y1_output_loss: 0.4614 - val_y2_output_loss: 2.0064 - val_y1_output_root_mean_squared_error: 0.6889 - val_y2_output_root_mean_squared_error: 1.4033
# Epoch 113/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.6025 - y1_output_loss: 0.5133 - y2_output_loss: 2.0934 - y1_output_root_mean_squared_error: 0.7171 - y2_output_root_mean_squared_error: 1.4451 - val_loss: 3.3928 - val_y1_output_loss: 0.4022 - val_y2_output_loss: 2.9146 - val_y1_output_root_mean_squared_error: 0.6398 - val_y2_output_root_mean_squared_error: 1.7273
# Epoch 114/500
# 614/614 [==============================] - 0s 126us/sample - loss: 2.1898 - y1_output_loss: 0.4284 - y2_output_loss: 1.7524 - y1_output_root_mean_squared_error: 0.6501 - y2_output_root_mean_squared_error: 1.3294 - val_loss: 3.3376 - val_y1_output_loss: 0.6972 - val_y2_output_loss: 2.7698 - val_y1_output_root_mean_squared_error: 0.8309 - val_y2_output_root_mean_squared_error: 1.6270
# Epoch 115/500
# 614/614 [==============================] - 0s 133us/sample - loss: 2.3116 - y1_output_loss: 0.4895 - y2_output_loss: 1.8073 - y1_output_root_mean_squared_error: 0.7018 - y2_output_root_mean_squared_error: 1.3487 - val_loss: 2.6109 - val_y1_output_loss: 0.4619 - val_y2_output_loss: 2.1055 - val_y1_output_root_mean_squared_error: 0.6753 - val_y2_output_root_mean_squared_error: 1.4679
# Epoch 116/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.7204 - y1_output_loss: 0.5129 - y2_output_loss: 2.1917 - y1_output_root_mean_squared_error: 0.7192 - y2_output_root_mean_squared_error: 1.4843 - val_loss: 2.4275 - val_y1_output_loss: 0.4221 - val_y2_output_loss: 2.0600 - val_y1_output_root_mean_squared_error: 0.6494 - val_y2_output_root_mean_squared_error: 1.4163
# Epoch 117/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.0521 - y1_output_loss: 0.4196 - y2_output_loss: 1.6341 - y1_output_root_mean_squared_error: 0.6475 - y2_output_root_mean_squared_error: 1.2778 - val_loss: 4.4329 - val_y1_output_loss: 0.9684 - val_y2_output_loss: 3.5931 - val_y1_output_root_mean_squared_error: 0.9938 - val_y2_output_root_mean_squared_error: 1.8561
# Epoch 118/500
# 614/614 [==============================] - 0s 128us/sample - loss: 2.5295 - y1_output_loss: 0.5637 - y2_output_loss: 1.9462 - y1_output_root_mean_squared_error: 0.7538 - y2_output_root_mean_squared_error: 1.4005 - val_loss: 3.3689 - val_y1_output_loss: 0.8855 - val_y2_output_loss: 2.5745 - val_y1_output_root_mean_squared_error: 0.9542 - val_y2_output_root_mean_squared_error: 1.5679
# Epoch 119/500
# 614/614 [==============================] - 0s 127us/sample - loss: 2.1774 - y1_output_loss: 0.4485 - y2_output_loss: 1.7099 - y1_output_root_mean_squared_error: 0.6723 - y2_output_root_mean_squared_error: 1.3136 - val_loss: 2.1369 - val_y1_output_loss: 0.4652 - val_y2_output_loss: 1.6665 - val_y1_output_root_mean_squared_error: 0.6897 - val_y2_output_root_mean_squared_error: 1.2889
# Epoch 120/500
# 614/614 [==============================] - 0s 125us/sample - loss: 2.0211 - y1_output_loss: 0.4082 - y2_output_loss: 1.6117 - y1_output_root_mean_squared_error: 0.6409 - y2_output_root_mean_squared_error: 1.2690 - val_loss: 3.8514 - val_y1_output_loss: 0.5254 - val_y2_output_loss: 3.5386 - val_y1_output_root_mean_squared_error: 0.7271 - val_y2_output_root_mean_squared_error: 1.8228
# Epoch 121/500
# ...
# Epoch 461/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3783 - y1_output_loss: 0.1088 - y2_output_loss: 0.2730 - y1_output_root_mean_squared_error: 0.3278 - y2_output_root_mean_squared_error: 0.5204 - val_loss: 2.3653 - val_y1_output_loss: 0.6524 - val_y2_output_loss: 1.7111 - val_y1_output_root_mean_squared_error: 0.7939 - val_y2_output_root_mean_squared_error: 1.3172
# Epoch 462/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.4760 - y1_output_loss: 0.1209 - y2_output_loss: 0.3511 - y1_output_root_mean_squared_error: 0.3488 - y2_output_root_mean_squared_error: 0.5952 - val_loss: 1.3510 - val_y1_output_loss: 0.4453 - val_y2_output_loss: 0.8999 - val_y1_output_root_mean_squared_error: 0.6573 - val_y2_output_root_mean_squared_error: 0.9587
# Epoch 463/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3212 - y1_output_loss: 0.1016 - y2_output_loss: 0.2234 - y1_output_root_mean_squared_error: 0.3178 - y2_output_root_mean_squared_error: 0.4692 - val_loss: 1.1103 - val_y1_output_loss: 0.3308 - val_y2_output_loss: 0.7600 - val_y1_output_root_mean_squared_error: 0.5830 - val_y2_output_root_mean_squared_error: 0.8777
# Epoch 464/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.7132 - y1_output_loss: 0.1769 - y2_output_loss: 0.5312 - y1_output_root_mean_squared_error: 0.4225 - y2_output_root_mean_squared_error: 0.7312 - val_loss: 1.0297 - val_y1_output_loss: 0.3052 - val_y2_output_loss: 0.7056 - val_y1_output_root_mean_squared_error: 0.5499 - val_y2_output_root_mean_squared_error: 0.8528
# Epoch 465/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3607 - y1_output_loss: 0.1075 - y2_output_loss: 0.2511 - y1_output_root_mean_squared_error: 0.3285 - y2_output_root_mean_squared_error: 0.5028 - val_loss: 0.6749 - val_y1_output_loss: 0.2448 - val_y2_output_loss: 0.4304 - val_y1_output_root_mean_squared_error: 0.4951 - val_y2_output_root_mean_squared_error: 0.6556
# Epoch 466/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3370 - y1_output_loss: 0.1067 - y2_output_loss: 0.2279 - y1_output_root_mean_squared_error: 0.3273 - y2_output_root_mean_squared_error: 0.4794 - val_loss: 0.7063 - val_y1_output_loss: 0.2453 - val_y2_output_loss: 0.4556 - val_y1_output_root_mean_squared_error: 0.4965 - val_y2_output_root_mean_squared_error: 0.6781
# Epoch 467/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.4171 - y1_output_loss: 0.1322 - y2_output_loss: 0.2821 - y1_output_root_mean_squared_error: 0.3645 - y2_output_root_mean_squared_error: 0.5331 - val_loss: 0.7782 - val_y1_output_loss: 0.2701 - val_y2_output_loss: 0.5125 - val_y1_output_root_mean_squared_error: 0.5278 - val_y2_output_root_mean_squared_error: 0.7068
# Epoch 468/500
# 614/614 [==============================] - 0s 140us/sample - loss: 0.3835 - y1_output_loss: 0.1054 - y2_output_loss: 0.2751 - y1_output_root_mean_squared_error: 0.3258 - y2_output_root_mean_squared_error: 0.5266 - val_loss: 0.6444 - val_y1_output_loss: 0.2406 - val_y2_output_loss: 0.3903 - val_y1_output_root_mean_squared_error: 0.4962 - val_y2_output_root_mean_squared_error: 0.6310
# Epoch 469/500
# 614/614 [==============================] - 0s 137us/sample - loss: 0.3035 - y1_output_loss: 0.1019 - y2_output_loss: 0.2040 - y1_output_root_mean_squared_error: 0.3203 - y2_output_root_mean_squared_error: 0.4482 - val_loss: 1.0022 - val_y1_output_loss: 0.2906 - val_y2_output_loss: 0.6800 - val_y1_output_root_mean_squared_error: 0.5462 - val_y2_output_root_mean_squared_error: 0.8390
# Epoch 470/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3630 - y1_output_loss: 0.1116 - y2_output_loss: 0.2527 - y1_output_root_mean_squared_error: 0.3345 - y2_output_root_mean_squared_error: 0.5011 - val_loss: 0.9505 - val_y1_output_loss: 0.2503 - val_y2_output_loss: 0.6811 - val_y1_output_root_mean_squared_error: 0.5023 - val_y2_output_root_mean_squared_error: 0.8356
# Epoch 471/500
# 614/614 [==============================] - 0s 128us/sample - loss: 0.3576 - y1_output_loss: 0.1042 - y2_output_loss: 0.2514 - y1_output_root_mean_squared_error: 0.3241 - y2_output_root_mean_squared_error: 0.5026 - val_loss: 0.8543 - val_y1_output_loss: 0.2577 - val_y2_output_loss: 0.6075 - val_y1_output_root_mean_squared_error: 0.5160 - val_y2_output_root_mean_squared_error: 0.7668
# Epoch 472/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4162 - y1_output_loss: 0.1166 - y2_output_loss: 0.2959 - y1_output_root_mean_squared_error: 0.3429 - y2_output_root_mean_squared_error: 0.5464 - val_loss: 0.6990 - val_y1_output_loss: 0.2590 - val_y2_output_loss: 0.4432 - val_y1_output_root_mean_squared_error: 0.5101 - val_y2_output_root_mean_squared_error: 0.6623
# Epoch 473/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.3848 - y1_output_loss: 0.1065 - y2_output_loss: 0.2763 - y1_output_root_mean_squared_error: 0.3277 - y2_output_root_mean_squared_error: 0.5267 - val_loss: 0.7708 - val_y1_output_loss: 0.2362 - val_y2_output_loss: 0.5141 - val_y1_output_root_mean_squared_error: 0.4907 - val_y2_output_root_mean_squared_error: 0.7280
# Epoch 474/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3290 - y1_output_loss: 0.1022 - y2_output_loss: 0.2259 - y1_output_root_mean_squared_error: 0.3190 - y2_output_root_mean_squared_error: 0.4768 - val_loss: 0.7141 - val_y1_output_loss: 0.2653 - val_y2_output_loss: 0.4517 - val_y1_output_root_mean_squared_error: 0.5153 - val_y2_output_root_mean_squared_error: 0.6698
# Epoch 475/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3340 - y1_output_loss: 0.1070 - y2_output_loss: 0.2245 - y1_output_root_mean_squared_error: 0.3286 - y2_output_root_mean_squared_error: 0.4754 - val_loss: 0.7120 - val_y1_output_loss: 0.2427 - val_y2_output_loss: 0.4758 - val_y1_output_root_mean_squared_error: 0.4989 - val_y2_output_root_mean_squared_error: 0.6805
# Epoch 476/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3340 - y1_output_loss: 0.1012 - y2_output_loss: 0.2382 - y1_output_root_mean_squared_error: 0.3170 - y2_output_root_mean_squared_error: 0.4832 - val_loss: 1.2255 - val_y1_output_loss: 0.3345 - val_y2_output_loss: 0.8588 - val_y1_output_root_mean_squared_error: 0.5796 - val_y2_output_root_mean_squared_error: 0.9432
# Epoch 477/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.3360 - y1_output_loss: 0.1065 - y2_output_loss: 0.2323 - y1_output_root_mean_squared_error: 0.3232 - y2_output_root_mean_squared_error: 0.4812 - val_loss: 0.9494 - val_y1_output_loss: 0.4358 - val_y2_output_loss: 0.5174 - val_y1_output_root_mean_squared_error: 0.6501 - val_y2_output_root_mean_squared_error: 0.7258
# Epoch 478/500
# 614/614 [==============================] - 0s 136us/sample - loss: 0.2915 - y1_output_loss: 0.0959 - y2_output_loss: 0.1937 - y1_output_root_mean_squared_error: 0.3101 - y2_output_root_mean_squared_error: 0.4419 - val_loss: 0.7314 - val_y1_output_loss: 0.2553 - val_y2_output_loss: 0.4670 - val_y1_output_root_mean_squared_error: 0.5069 - val_y2_output_root_mean_squared_error: 0.6888
# Epoch 479/500
# 614/614 [==============================] - 0s 125us/sample - loss: 0.4705 - y1_output_loss: 0.1494 - y2_output_loss: 0.3184 - y1_output_root_mean_squared_error: 0.3870 - y2_output_root_mean_squared_error: 0.5663 - val_loss: 0.7280 - val_y1_output_loss: 0.2869 - val_y2_output_loss: 0.4402 - val_y1_output_root_mean_squared_error: 0.5405 - val_y2_output_root_mean_squared_error: 0.6602
# Epoch 480/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.2825 - y1_output_loss: 0.0950 - y2_output_loss: 0.1873 - y1_output_root_mean_squared_error: 0.3069 - y2_output_root_mean_squared_error: 0.4340 - val_loss: 0.8022 - val_y1_output_loss: 0.2409 - val_y2_output_loss: 0.5494 - val_y1_output_root_mean_squared_error: 0.4956 - val_y2_output_root_mean_squared_error: 0.7461
# Epoch 481/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3255 - y1_output_loss: 0.1092 - y2_output_loss: 0.2142 - y1_output_root_mean_squared_error: 0.3312 - y2_output_root_mean_squared_error: 0.4646 - val_loss: 0.6908 - val_y1_output_loss: 0.2661 - val_y2_output_loss: 0.4210 - val_y1_output_root_mean_squared_error: 0.5182 - val_y2_output_root_mean_squared_error: 0.6498
# Epoch 482/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.2901 - y1_output_loss: 0.1008 - y2_output_loss: 0.1888 - y1_output_root_mean_squared_error: 0.3169 - y2_output_root_mean_squared_error: 0.4355 - val_loss: 0.7170 - val_y1_output_loss: 0.2861 - val_y2_output_loss: 0.4271 - val_y1_output_root_mean_squared_error: 0.5384 - val_y2_output_root_mean_squared_error: 0.6536
# Epoch 483/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.4474 - y1_output_loss: 0.1050 - y2_output_loss: 0.3393 - y1_output_root_mean_squared_error: 0.3246 - y2_output_root_mean_squared_error: 0.5849 - val_loss: 0.6634 - val_y1_output_loss: 0.2531 - val_y2_output_loss: 0.4107 - val_y1_output_root_mean_squared_error: 0.5060 - val_y2_output_root_mean_squared_error: 0.6382
# Epoch 484/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3635 - y1_output_loss: 0.1028 - y2_output_loss: 0.2615 - y1_output_root_mean_squared_error: 0.3202 - y2_output_root_mean_squared_error: 0.5108 - val_loss: 1.2469 - val_y1_output_loss: 0.4485 - val_y2_output_loss: 0.7889 - val_y1_output_root_mean_squared_error: 0.6604 - val_y2_output_root_mean_squared_error: 0.9004
# Epoch 485/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.3351 - y1_output_loss: 0.1162 - y2_output_loss: 0.2178 - y1_output_root_mean_squared_error: 0.3417 - y2_output_root_mean_squared_error: 0.4673 - val_loss: 0.6284 - val_y1_output_loss: 0.2246 - val_y2_output_loss: 0.4011 - val_y1_output_root_mean_squared_error: 0.4799 - val_y2_output_root_mean_squared_error: 0.6309
# Epoch 486/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4923 - y1_output_loss: 0.1313 - y2_output_loss: 0.3583 - y1_output_root_mean_squared_error: 0.3626 - y2_output_root_mean_squared_error: 0.6007 - val_loss: 0.7569 - val_y1_output_loss: 0.2710 - val_y2_output_loss: 0.5029 - val_y1_output_root_mean_squared_error: 0.5190 - val_y2_output_root_mean_squared_error: 0.6982
# Epoch 487/500
# 614/614 [==============================] - 0s 129us/sample - loss: 0.3083 - y1_output_loss: 0.0989 - y2_output_loss: 0.2187 - y1_output_root_mean_squared_error: 0.3149 - y2_output_root_mean_squared_error: 0.4573 - val_loss: 2.5198 - val_y1_output_loss: 0.4651 - val_y2_output_loss: 2.1410 - val_y1_output_root_mean_squared_error: 0.6894 - val_y2_output_root_mean_squared_error: 1.4299
# Epoch 488/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.5160 - y1_output_loss: 0.1303 - y2_output_loss: 0.3839 - y1_output_root_mean_squared_error: 0.3596 - y2_output_root_mean_squared_error: 0.6218 - val_loss: 0.6291 - val_y1_output_loss: 0.2332 - val_y2_output_loss: 0.3875 - val_y1_output_root_mean_squared_error: 0.4884 - val_y2_output_root_mean_squared_error: 0.6250
# Epoch 489/500
# 614/614 [==============================] - 0s 123us/sample - loss: 0.4286 - y1_output_loss: 0.1262 - y2_output_loss: 0.3002 - y1_output_root_mean_squared_error: 0.3563 - y2_output_root_mean_squared_error: 0.5492 - val_loss: 0.9924 - val_y1_output_loss: 0.3263 - val_y2_output_loss: 0.6493 - val_y1_output_root_mean_squared_error: 0.5695 - val_y2_output_root_mean_squared_error: 0.8174
# Epoch 490/500
# 614/614 [==============================] - 0s 131us/sample - loss: 0.3165 - y1_output_loss: 0.1026 - y2_output_loss: 0.2135 - y1_output_root_mean_squared_error: 0.3216 - y2_output_root_mean_squared_error: 0.4615 - val_loss: 0.9675 - val_y1_output_loss: 0.2719 - val_y2_output_loss: 0.6762 - val_y1_output_root_mean_squared_error: 0.5231 - val_y2_output_root_mean_squared_error: 0.8330
# Epoch 491/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3191 - y1_output_loss: 0.0942 - y2_output_loss: 0.2265 - y1_output_root_mean_squared_error: 0.3040 - y2_output_root_mean_squared_error: 0.4762 - val_loss: 0.7191 - val_y1_output_loss: 0.2322 - val_y2_output_loss: 0.4732 - val_y1_output_root_mean_squared_error: 0.4859 - val_y2_output_root_mean_squared_error: 0.6950
# Epoch 492/500
# 614/614 [==============================] - 0s 133us/sample - loss: 0.3068 - y1_output_loss: 0.1066 - y2_output_loss: 0.2028 - y1_output_root_mean_squared_error: 0.3249 - y2_output_root_mean_squared_error: 0.4486 - val_loss: 1.3378 - val_y1_output_loss: 0.2752 - val_y2_output_loss: 1.0362 - val_y1_output_root_mean_squared_error: 0.5221 - val_y2_output_root_mean_squared_error: 1.0321
# Epoch 493/500
# 614/614 [==============================] - 0s 127us/sample - loss: 0.3496 - y1_output_loss: 0.1074 - y2_output_loss: 0.2392 - y1_output_root_mean_squared_error: 0.3292 - y2_output_root_mean_squared_error: 0.4912 - val_loss: 0.7102 - val_y1_output_loss: 0.2800 - val_y2_output_loss: 0.4346 - val_y1_output_root_mean_squared_error: 0.5308 - val_y2_output_root_mean_squared_error: 0.6546
# Epoch 494/500
# 614/614 [==============================] - 0s 126us/sample - loss: 0.4060 - y1_output_loss: 0.1220 - y2_output_loss: 0.2816 - y1_output_root_mean_squared_error: 0.3508 - y2_output_root_mean_squared_error: 0.5319 - val_loss: 0.8105 - val_y1_output_loss: 0.2355 - val_y2_output_loss: 0.5889 - val_y1_output_root_mean_squared_error: 0.4881 - val_y2_output_root_mean_squared_error: 0.7565
# Epoch 495/500
# 614/614 [==============================] - 0s 143us/sample - loss: 0.3616 - y1_output_loss: 0.1008 - y2_output_loss: 0.2645 - y1_output_root_mean_squared_error: 0.3177 - y2_output_root_mean_squared_error: 0.5106 - val_loss: 1.2907 - val_y1_output_loss: 0.4340 - val_y2_output_loss: 0.8386 - val_y1_output_root_mean_squared_error: 0.6559 - val_y2_output_root_mean_squared_error: 0.9276
# Epoch 496/500
# 614/614 [==============================] - 0s 134us/sample - loss: 0.3342 - y1_output_loss: 0.1044 - y2_output_loss: 0.2276 - y1_output_root_mean_squared_error: 0.3244 - y2_output_root_mean_squared_error: 0.4785 - val_loss: 0.7669 - val_y1_output_loss: 0.2418 - val_y2_output_loss: 0.5084 - val_y1_output_root_mean_squared_error: 0.4930 - val_y2_output_root_mean_squared_error: 0.7238
# Epoch 497/500
# 614/614 [==============================] - 0s 138us/sample - loss: 0.4146 - y1_output_loss: 0.1110 - y2_output_loss: 0.3042 - y1_output_root_mean_squared_error: 0.3343 - y2_output_root_mean_squared_error: 0.5503 - val_loss: 0.8884 - val_y1_output_loss: 0.2457 - val_y2_output_loss: 0.6246 - val_y1_output_root_mean_squared_error: 0.5022 - val_y2_output_root_mean_squared_error: 0.7976
# Epoch 498/500
# 614/614 [==============================] - 0s 130us/sample - loss: 0.4018 - y1_output_loss: 0.1125 - y2_output_loss: 0.2889 - y1_output_root_mean_squared_error: 0.3333 - y2_output_root_mean_squared_error: 0.5391 - val_loss: 0.9509 - val_y1_output_loss: 0.2537 - val_y2_output_loss: 0.7315 - val_y1_output_root_mean_squared_error: 0.5017 - val_y2_output_root_mean_squared_error: 0.8362
# Epoch 499/500
# 614/614 [==============================] - 0s 123us/sample - loss: 0.2918 - y1_output_loss: 0.0950 - y2_output_loss: 0.1973 - y1_output_root_mean_squared_error: 0.3059 - y2_output_root_mean_squared_error: 0.4452 - val_loss: 0.6869 - val_y1_output_loss: 0.2722 - val_y2_output_loss: 0.4170 - val_y1_output_root_mean_squared_error: 0.5196 - val_y2_output_root_mean_squared_error: 0.6456
# Epoch 500/500
# 614/614 [==============================] - 0s 132us/sample - loss: 0.2769 - y1_output_loss: 0.0953 - y2_output_loss: 0.1823 - y1_output_root_mean_squared_error: 0.3057 - y2_output_root_mean_squared_error: 0.4283 - val_loss: 0.7171 - val_y1_output_loss: 0.2623 - val_y2_output_loss: 0.4628 - val_y1_output_root_mean_squared_error: 0.5190 - val_y2_output_root_mean_squared_error: 0.6692

# %% [markdown]
# ## Evaluate the Model and Plot Metrics

# %%
# Test the model and print loss and mse for both outputs
loss, Y1_loss, Y2_loss, Y1_rmse, Y2_rmse = model.evaluate(x=norm_test_X, y=test_Y)
print("Loss = {}, Y1_loss = {}, Y1_mse = {}, Y2_loss = {}, Y2_mse = {}".format(loss, Y1_loss, Y1_rmse, Y2_loss, Y2_rmse))
# Out:
# 154/154 [==============================] - 0s 38us/sample - loss: 0.7171 - y1_output_loss: 0.2663 - y2_output_loss: 0.4544 - y1_output_root_mean_squared_error: 0.5190 - y2_output_root_mean_squared_error: 0.6692
# Loss = 0.7171440170956896, Y1_loss = 0.26628389954566956, Y1_mse = 0.5189563632011414, Y2_loss = 0.45439815521240234, Y2_mse = 0.6691997051239014

# %%
# Plot the loss and mse
Y_pred = model.predict(norm_test_X)
plot_diff(test_Y[0], Y_pred[0], title='Y1')
plot_diff(test_Y[1], Y_pred[1], title='Y2')
plot_metrics(metric_name='y1_output_root_mean_squared_error', title='Y1 RMSE', ylim=6)
plot_metrics(metric_name='y2_output_root_mean_squared_error', title='Y2 RMSE', ylim=7)
